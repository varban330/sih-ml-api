# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# ## Electricity

# %%
dataset = pd.read_csv('Electricity/Electricity.csv')
dataset
# Out:
#    Grievance Subject Issue with - Electricity/AC  Quantity of Parts - (OFP)  \
# 0           Not Reqd                 ELECTRICITY                         10
# 1           Not Reqd                 ELECTRICITY                         15
# 2           Not Reqd                          AC                          5
# 3           Not Reqd                 ELECTRICITY                          5
# 4           Not Reqd                 ELECTRICITY                          7
# 5           Not Reqd                          AC                         11
# 6           Not Reqd                          AC                          7
# 7           Not Reqd                          AC                         14
# 8           Not Reqd                          AC                          9
# 9           Not Reqd                          AC                          6
# 10          Not Reqd                          AC                         14
# 11          Not Reqd                          AC                         10
# 12          Not Reqd                          AC                         12
# 13          Not Reqd                 ELECTRICITY                         11
# 14          Not Reqd                          AC                         15
# 15          Not Reqd                          AC                         11
# 16          Not Reqd                 ELECTRICITY                         11
# 17          Not Reqd                 ELECTRICITY                         15
# 18          Not Reqd                          AC                          7
# 19          Not Reqd                 ELECTRICITY                          7
# 20          Not Reqd                          AC                         10
# 21          Not Reqd                 ELECTRICITY                         10
# 22          Not Reqd                          AC                         13
# 23          Not Reqd                 ELECTRICITY                         12
# 24          Not Reqd                 ELECTRICITY                          5
# 25          Not Reqd                          AC                         13
# 26          Not Reqd                          AC                         15
# 27          Not Reqd                          AC                         10
# 28          Not Reqd                          AC                         15
# 29          Not Reqd                 ELECTRICITY                         14
# 30          Not Reqd                          AC                          8
# 31          Not Reqd                 ELECTRICITY                         10
# 32          Not Reqd                          AC                          7
# 33          Not Reqd                          AC                         13
# 34          Not Reqd                          AC                          5
# 35          Not Reqd                 ELECTRICITY                         14
# 36          Not Reqd                          AC                         13
# 37          Not Reqd                          AC                         12
# 38          Not Reqd                          AC                          7
# 39          Not Reqd                 ELECTRICITY                         14
# 40          Not Reqd                          AC                         11
# 41          Not Reqd                          AC                         12
# 42          Not Reqd                 ELECTRICITY                          6
# 43          Not Reqd                          AC                          6
# 44          Not Reqd                 ELECTRICITY                          7
# 45          Not Reqd                          AC                          7
# 46          Not Reqd                 ELECTRICITY                         14
# 47          Not Reqd                 ELECTRICITY                          7
# 48          Not Reqd                          AC                         15
#
#    Availablity - Available/Need to Order - (OFP)  \
# 0                                      Available
# 1                                  Need To Order
# 2                                      Available
# 3                                  Need To Order
# 4                                      Available
# 5                                      Available
# 6                                      Available
# 7                                      Available
# 8                                      Available
# 9                                  Need To Order
# 10                                     Available
# 11                                 Need To Order
# 12                                     Available
# 13                                 Need To Order
# 14                                     Available
# 15                                 Need To Order
# 16                                     Available
# 17                                 Need To Order
# 18                                     Available
# 19                                 Need To Order
# 20                                     Available
# 21                                 Need To Order
# 22                                     Available
# 23                                     Available
# 24                                     Available
# 25                                 Need To Order
# 26                                 Need To Order
# 27                                 Need To Order
# 28                                     Available
# 29                                     Available
# 30                                     Available
# 31                                     Available
# 32                                     Available
# 33                                 Need To Order
# 34                                 Need To Order
# 35                                 Need To Order
# 36                                 Need To Order
# 37                                 Need To Order
# 38                                 Need To Order
# 39                                 Need To Order
# 40                                 Need To Order
# 41                                     Available
# 42                                 Need To Order
# 43                                 Need To Order
# 44                                     Available
# 45                                     Available
# 46                                 Need To Order
# 47                                     Available
# 48                                 Need To Order
#
#    Need of external expert - (OFP) Suitable time for visit  \
# 0                               No                16:31:33
# 1                              Yes                17:04:32
# 2                               No                09:13:21
# 3                               No                14:29:59
# 4                              Yes                10:28:12
# 5                               No                15:22:06
# 6                               No                17:59:06
# 7                               No                14:51:50
# 8                              Yes                11:34:54
# 9                               No                12:23:12
# 10                             Yes                16:40:19
# 11                              No                15:19:26
# 12                              No                18:38:14
# 13                              No                10:06:50
# 14                             Yes                14:53:01
# 15                             Yes                16:46:41
# 16                              No                14:09:33
# 17                              No                10:05:52
# 18                              No                18:44:46
# 19                              No                09:29:07
# 20                             Yes                15:15:11
# 21                             Yes                15:20:51
# 22                              No                10:09:11
# 23                              No                10:47:43
# 24                             Yes                12:23:46
# 25                             Yes                18:57:19
# 26                              No                12:58:30
# 27                              No                10:36:06
# 28                             Yes                10:00:02
# 29                              No                14:17:07
# 30                              No                14:02:09
# 31                              No                10:49:06
# 32                             Yes                18:24:47
# 33                             Yes                12:37:23
# 34                              No                15:31:56
# 35                             Yes                18:48:08
# 36                              No                18:39:40
# 37                              No                11:46:09
# 38                             Yes                11:54:20
# 39                              No                12:44:27
# 40                              No                09:12:43
# 41                              No                17:53:25
# 42                              No                13:40:31
# 43                             Yes                13:56:05
# 44                             Yes                15:34:37
# 45                              No                18:25:32
# 46                             Yes                17:06:32
# 47                              No                17:33:11
# 48                             Yes                11:42:53
#
#    Grievance Description  Days till response
# 0               Not Reqd                  13
# 1               Not Reqd                   3
# 2               Not Reqd                   7
# 3               Not Reqd                   3
# 4               Not Reqd                   6
# 5               Not Reqd                  13
# 6               Not Reqd                   3
# 7               Not Reqd                  15
# 8               Not Reqd                  10
# 9               Not Reqd                   8
# 10              Not Reqd                  12
# 11              Not Reqd                  10
# 12              Not Reqd                  11
# 13              Not Reqd                   7
# 14              Not Reqd                   2
# 15              Not Reqd                   8
# 16              Not Reqd                   3
# 17              Not Reqd                   9
# 18              Not Reqd                  15
# 19              Not Reqd                   6
# 20              Not Reqd                   3
# 21              Not Reqd                   5
# 22              Not Reqd                   8
# 23              Not Reqd                  11
# 24              Not Reqd                  12
# 25              Not Reqd                  12
# 26              Not Reqd                   9
# 27              Not Reqd                   5
# 28              Not Reqd                   7
# 29              Not Reqd                  14
# 30              Not Reqd                   3
# 31              Not Reqd                  13
# 32              Not Reqd                   6
# 33              Not Reqd                  11
# 34              Not Reqd                   6
# 35              Not Reqd                  14
# 36              Not Reqd                   5
# 37              Not Reqd                  12
# 38              Not Reqd                   1
# 39              Not Reqd                   5
# 40              Not Reqd                   8
# 41              Not Reqd                   2
# 42              Not Reqd                  11
# 43              Not Reqd                  11
# 44              Not Reqd                  12
# 45              Not Reqd                   2
# 46              Not Reqd                  13
# 47              Not Reqd                   1
# 48              Not Reqd                   3

# %%
k = [1,2,3,4]
df = dataset.iloc[:, k] 
X = dataset.iloc[:, k].values
Y = dataset.iloc[:, 7].values
len(X[0])
df
# Out:
#    Issue with - Electricity/AC  Quantity of Parts - (OFP)  \
# 0                  ELECTRICITY                         10
# 1                  ELECTRICITY                         15
# 2                           AC                          5
# 3                  ELECTRICITY                          5
# 4                  ELECTRICITY                          7
# 5                           AC                         11
# 6                           AC                          7
# 7                           AC                         14
# 8                           AC                          9
# 9                           AC                          6
# 10                          AC                         14
# 11                          AC                         10
# 12                          AC                         12
# 13                 ELECTRICITY                         11
# 14                          AC                         15
# 15                          AC                         11
# 16                 ELECTRICITY                         11
# 17                 ELECTRICITY                         15
# 18                          AC                          7
# 19                 ELECTRICITY                          7
# 20                          AC                         10
# 21                 ELECTRICITY                         10
# 22                          AC                         13
# 23                 ELECTRICITY                         12
# 24                 ELECTRICITY                          5
# 25                          AC                         13
# 26                          AC                         15
# 27                          AC                         10
# 28                          AC                         15
# 29                 ELECTRICITY                         14
# 30                          AC                          8
# 31                 ELECTRICITY                         10
# 32                          AC                          7
# 33                          AC                         13
# 34                          AC                          5
# 35                 ELECTRICITY                         14
# 36                          AC                         13
# 37                          AC                         12
# 38                          AC                          7
# 39                 ELECTRICITY                         14
# 40                          AC                         11
# 41                          AC                         12
# 42                 ELECTRICITY                          6
# 43                          AC                          6
# 44                 ELECTRICITY                          7
# 45                          AC                          7
# 46                 ELECTRICITY                         14
# 47                 ELECTRICITY                          7
# 48                          AC                         15
#
#    Availablity - Available/Need to Order - (OFP)  \
# 0                                      Available
# 1                                  Need To Order
# 2                                      Available
# 3                                  Need To Order
# 4                                      Available
# 5                                      Available
# 6                                      Available
# 7                                      Available
# 8                                      Available
# 9                                  Need To Order
# 10                                     Available
# 11                                 Need To Order
# 12                                     Available
# 13                                 Need To Order
# 14                                     Available
# 15                                 Need To Order
# 16                                     Available
# 17                                 Need To Order
# 18                                     Available
# 19                                 Need To Order
# 20                                     Available
# 21                                 Need To Order
# 22                                     Available
# 23                                     Available
# 24                                     Available
# 25                                 Need To Order
# 26                                 Need To Order
# 27                                 Need To Order
# 28                                     Available
# 29                                     Available
# 30                                     Available
# 31                                     Available
# 32                                     Available
# 33                                 Need To Order
# 34                                 Need To Order
# 35                                 Need To Order
# 36                                 Need To Order
# 37                                 Need To Order
# 38                                 Need To Order
# 39                                 Need To Order
# 40                                 Need To Order
# 41                                     Available
# 42                                 Need To Order
# 43                                 Need To Order
# 44                                     Available
# 45                                     Available
# 46                                 Need To Order
# 47                                     Available
# 48                                 Need To Order
#
#    Need of external expert - (OFP)
# 0                               No
# 1                              Yes
# 2                               No
# 3                               No
# 4                              Yes
# 5                               No
# 6                               No
# 7                               No
# 8                              Yes
# 9                               No
# 10                             Yes
# 11                              No
# 12                              No
# 13                              No
# 14                             Yes
# 15                             Yes
# 16                              No
# 17                              No
# 18                              No
# 19                              No
# 20                             Yes
# 21                             Yes
# 22                              No
# 23                              No
# 24                             Yes
# 25                             Yes
# 26                              No
# 27                              No
# 28                             Yes
# 29                              No
# 30                              No
# 31                              No
# 32                             Yes
# 33                             Yes
# 34                              No
# 35                             Yes
# 36                              No
# 37                              No
# 38                             Yes
# 39                              No
# 40                              No
# 41                              No
# 42                              No
# 43                             Yes
# 44                             Yes
# 45                              No
# 46                             Yes
# 47                              No
# 48                             Yes

# %%
# Save Encoder Objects for new incoming data
import pickle
encx0 = LabelEncoder().fit(X[:,0])
encx2 = LabelEncoder().fit(X[:,2])
encx3 = LabelEncoder().fit(X[:,3])
filename = 'Electricity/Electricityencx0.sav'
pickle.dump(encx0,open(filename,'wb'))
filename = 'Electricity/Electricityencx2.sav'
pickle.dump(encx2,open(filename,'wb'))
filename = 'Electricity/Electricityencx3.sav'
pickle.dump(encx3,open(filename,'wb'))

# %%
data = ['AC',5,'Available','No']

# %%
X[:,0] = encx0.transform(X[:,0])
X[:,2] = encx2.transform(X[:,2])
X[:,3] = encx3.transform(X[:,3])

# %%
print(max(X[:,0]))
# Out:
# 1

# %%
onehotencoder = OneHotEncoder(categorical_features=[0,2,3])
onehenc = onehotencoder.fit(X)
filename = 'Electricity/Electricity.sav'
pickle.dump(onehenc,open(filename,'wb'))
X = onehenc.transform(X).toarray()
d = encx0.transform([data[0]])
data[0] = d[0]
d = encx2.transform([data[2]])
data[2] = d[0]
d = encx3.transform([data[3]])
data[3] = d[0]
ar = np.array(data)
print(data)
ar = ar.reshape(1,-1)
kar=onehenc.transform(ar).toarray()
print(kar)
print(len(X[0]))
# Out:
# [0, 5, 0, 0]
# [[1. 0. 1. 0. 1. 0. 5.]]
# 7

# %%
k = list()
notlist = [0,2,4]
for i in range(7):
    if i not in notlist:
        k.append(i)
X = X[:,k]
kar = kar[:,k]

# %%
print((kar[0]))
# Out:
# [0. 0. 0. 5.]

# %% [markdown]
# ## SVR

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model1 = SVR(kernel='rbf')
model1.fit(X_train,Y_train)
Y_pred = model1.predict(X_test)

# %%
Y_pred
# Out:
# array([7.81701478, 7.57557363, 7.10012577, 7.13603168, 7.40384018,
#        8.16965358, 7.67316233, 7.93279126, 7.46915964, 7.81699651])

# %%
Y_test
# Out:
# array([14,  6,  9,  3,  6, 12,  6,  8, 15, 12])

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'C':[1,10,100,1000], 'kernel': ['rbf'], 'gamma':[0.05,0.01,0.001,0.0001]},
             {'C':[100,200,300,400], 'kernel': ['poly'], 'gamma':[0.05,0.06,0.07,0.08,0.09,0.1]},
             {'C':[1,10,100,1000], 'kernel': ['sigmoid'], 'gamma':[0.05,0.01,0.001,0.0001]}]
gridsearch = GridSearchCV(estimator=model1,
                         param_grid=parameters,
                         scoring='r2',
                         cv=10)
gridsearch = gridsearch.fit(X_train,Y_train)
print(gridsearch.best_score_)
print(gridsearch.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-d4bcd2e506b2> in <module>
#       7                          scoring='r2',
#       8                          cv=10)
# ----> 9 gridsearch = gridsearch.fit(X_train,Y_train)
#      10 print(gridsearch.best_score_)
#      11 print(gridsearch.best_params_)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     456             estimator.fit(X_train, **fit_params)
#     457         else:
# --> 458             estimator.fit(X_train, y_train, **fit_params)
#     459
#     460     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model2 = RandomForestRegressor(n_estimators=650, criterion='mse',random_state=0)
model2 = model2.fit(X,Y)

# %%
from sklearn.metrics import r2_score
Y_pred = model2.predict(X)
for i in Y_pred:
    print(round(i))
print(Y_test)
print(r2_score(Y,Y_pred))
# Out:
# 12.0
# 4.0
# 7.0
# 5.0
# 9.0
# 10.0
# 7.0
# 13.0
# 8.0
# 8.0
# 12.0
# 8.0
# 7.0
# 7.0
# 5.0
# 8.0
# 6.0
# 8.0
# 7.0
# 5.0
# 6.0
# 6.0
# 8.0
# 9.0
# 10.0
# 11.0
# 8.0
# 8.0
# 5.0
# 13.0
# 4.0
# 12.0
# 6.0
# 11.0
# 6.0
# 13.0
# 7.0
# 10.0
# 3.0
# 8.0
# 8.0
# 7.0
# 9.0
# 9.0
# 9.0
# 7.0
# 13.0
# 4.0
# 4.0
# [14  6  9  3  6 12  6  8 15 12]
# 0.662817797046954

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'n_estimators':[1,10,100,1000], 'criterion':['mse','mae']}]
grid_search = GridSearchCV(estimator=model2,
                          param_grid=parameters,
                          scoring='r2',
                          cv=10)
grid_search = grid_search.fit(X,Y)
print(grid_search.best_score_)
print(grid_search.best_params_)

# %%
import pickle
filename = 'Electricity/Electricitymodel.sav'
pickle.dump(model2,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(kar)
print(result)
from sklearn.metrics import r2_score
# Out:
# [12.28769231]

# %%
from sklearn.preprocessing import LabelEncoder
c = ['France', 'UK', 'US', 'US', 'UK', 'China', 'France']
enc = LabelEncoder().fit(c)
encoded = enc.transform(c)
print(encoded)

enc.transform(['France'])
# Out:
# [1 2 3 3 2 0 1]
# array([1])

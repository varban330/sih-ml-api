# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# ## Scholarship Portal

# %%
dataset = pd.read_csv('water_supply/water_supply.csv')
dataset
# Out:
#    Grievance Subject  Issue with - Drinking/Supply Parts needed  \
# 0           Not Reqd                      Drinking          Tap
# 1           Not Reqd                      Drinking          Tap
# 2           Not Reqd                        Supply          Tap
# 3           Not Reqd                        Supply          Tap
# 4           Not Reqd                      Drinking         Pipe
# 5           Not Reqd                      Drinking          Tap
# 6           Not Reqd                      Drinking          Tap
# 7           Not Reqd                      Drinking         Pipe
# 8           Not Reqd                        Supply      Bassers
# 9           Not Reqd                        Supply      Bassers
# 10          Not Reqd                      Drinking      Bassers
# 11          Not Reqd                        Supply          Tap
# 12          Not Reqd                      Drinking         Pipe
# 13          Not Reqd                        Supply         Pipe
# 14          Not Reqd                      Drinking          Tap
# 15          Not Reqd                        Supply          Tap
# 16          Not Reqd                        Supply          Tap
# 17          Not Reqd                        Supply          Tap
# 18          Not Reqd                        Supply      Bassers
# 19          Not Reqd                        Supply         Pipe
# 20          Not Reqd                      Drinking         Pipe
# 21          Not Reqd                        Supply         Pipe
# 22          Not Reqd                        Supply          Tap
# 23          Not Reqd                      Drinking         Pipe
# 24          Not Reqd                        Supply         Pipe
# 25          Not Reqd                      Drinking         Pipe
# 26          Not Reqd                        Supply      Bassers
# 27          Not Reqd                      Drinking         Pipe
# 28          Not Reqd                      Drinking          Tap
# 29          Not Reqd                        Supply          Tap
# 30          Not Reqd                      Drinking          Tap
# 31          Not Reqd                        Supply      Bassers
# 32          Not Reqd                        Supply          Tap
# 33          Not Reqd                        Supply          Tap
# 34          Not Reqd                        Supply          Tap
# 35          Not Reqd                        Supply          Tap
# 36          Not Reqd                        Supply          Tap
# 37          Not Reqd                      Drinking      Bassers
# 38          Not Reqd                      Drinking         Pipe
# 39          Not Reqd                      Drinking         Pipe
# 40          Not Reqd                      Drinking      Bassers
# 41          Not Reqd                        Supply         Pipe
# 42          Not Reqd                        Supply          Tap
# 43          Not Reqd                      Drinking         Pipe
# 44          Not Reqd                        Supply         Pipe
# 45          Not Reqd                      Drinking          Tap
# 46          Not Reqd                      Drinking          Tap
# 47          Not Reqd                      Drinking      Bassers
# 48          Not Reqd                        Supply         Pipe
#
#     Quantity of Parts - (OFP) Availablity - Available/Need to Order - (OFP)  \
# 0                          15                                 Need To Order
# 1                           7                                 Need To Order
# 2                          19                                 Need To Order
# 3                           4                                     Available
# 4                          14                                     Available
# 5                          25                                 Need To Order
# 6                          29                                     Available
# 7                          10                                     Available
# 8                          13                                     Available
# 9                           2                                 Need To Order
# 10                         21                                     Available
# 11                          6                                     Available
# 12                         26                                 Need To Order
# 13                         14                                 Need To Order
# 14                         22                                 Need To Order
# 15                         15                                     Available
# 16                         20                                 Need To Order
# 17                         13                                 Need To Order
# 18                         20                                 Need To Order
# 19                          7                                 Need To Order
# 20                         21                                     Available
# 21                          5                                 Need To Order
# 22                         12                                     Available
# 23                          9                                 Need To Order
# 24                         19                                 Need To Order
# 25                          8                                 Need To Order
# 26                         23                                     Available
# 27                         22                                 Need To Order
# 28                         24                                 Need To Order
# 29                          4                                 Need To Order
# 30                         14                                 Need To Order
# 31                         18                                 Need To Order
# 32                         26                                     Available
# 33                         25                                     Available
# 34                         19                                 Need To Order
# 35                         16                                     Available
# 36                         30                                 Need To Order
# 37                         10                                 Need To Order
# 38                         29                                 Need To Order
# 39                         16                                 Need To Order
# 40                         11                                     Available
# 41                          8                                     Available
# 42                         19                                 Need To Order
# 43                          3                                 Need To Order
# 44                         24                                     Available
# 45                          8                                     Available
# 46                         27                                     Available
# 47                         12                                     Available
# 48                         25                                     Available
#
#    Need of external expert - (OFP) Suitable time for visit  \
# 0                              Yes                11:20:45
# 1                               No                12:13:30
# 2                              Yes                10:31:47
# 3                               No                16:51:25
# 4                               No                16:06:32
# 5                              Yes                13:32:16
# 6                               No                11:41:12
# 7                               No                15:27:36
# 8                              Yes                18:46:48
# 9                              Yes                09:37:54
# 10                             Yes                10:23:16
# 11                             Yes                14:32:24
# 12                              No                12:32:03
# 13                             Yes                09:30:00
# 14                              No                13:13:28
# 15                             Yes                13:14:04
# 16                             Yes                09:21:25
# 17                             Yes                14:37:36
# 18                              No                17:03:10
# 19                              No                15:03:20
# 20                             Yes                10:09:18
# 21                              No                16:47:01
# 22                              No                14:38:36
# 23                             Yes                09:00:32
# 24                              No                09:29:49
# 25                              No                16:40:08
# 26                              No                13:55:44
# 27                             Yes                12:07:42
# 28                             Yes                16:32:33
# 29                              No                16:03:56
# 30                              No                14:15:21
# 31                              No                15:32:17
# 32                              No                18:39:06
# 33                             Yes                12:42:37
# 34                              No                11:21:51
# 35                              No                15:24:52
# 36                              No                11:31:50
# 37                             Yes                09:40:04
# 38                             Yes                17:50:54
# 39                              No                16:20:34
# 40                             Yes                15:51:05
# 41                             Yes                15:57:23
# 42                             Yes                09:14:41
# 43                              No                13:06:12
# 44                             Yes                16:39:14
# 45                             Yes                15:07:40
# 46                              No                12:21:36
# 47                              No                18:26:39
# 48                              No                17:44:43
#
#    Grievance Description  Days Till Response
# 0               Not Reqd                   6
# 1               Not Reqd                   5
# 2               Not Reqd                   8
# 3               Not Reqd                   4
# 4               Not Reqd                   8
# 5               Not Reqd                   3
# 6               Not Reqd                   5
# 7               Not Reqd                   5
# 8               Not Reqd                   3
# 9               Not Reqd                   7
# 10              Not Reqd                   4
# 11              Not Reqd                   7
# 12              Not Reqd                   7
# 13              Not Reqd                   4
# 14              Not Reqd                   3
# 15              Not Reqd                   8
# 16              Not Reqd                   9
# 17              Not Reqd                   3
# 18              Not Reqd                   6
# 19              Not Reqd                   4
# 20              Not Reqd                   6
# 21              Not Reqd                   5
# 22              Not Reqd                   5
# 23              Not Reqd                   7
# 24              Not Reqd                   4
# 25              Not Reqd                   4
# 26              Not Reqd                   2
# 27              Not Reqd                   4
# 28              Not Reqd                   7
# 29              Not Reqd                   7
# 30              Not Reqd                   7
# 31              Not Reqd                   7
# 32              Not Reqd                   3
# 33              Not Reqd                   4
# 34              Not Reqd                   7
# 35              Not Reqd                   8
# 36              Not Reqd                   7
# 37              Not Reqd                   6
# 38              Not Reqd                   5
# 39              Not Reqd                   4
# 40              Not Reqd                   3
# 41              Not Reqd                   5
# 42              Not Reqd                   8
# 43              Not Reqd                   6
# 44              Not Reqd                   3
# 45              Not Reqd                   3
# 46              Not Reqd                   4
# 47              Not Reqd                   8
# 48              Not Reqd                   4

# %%
k = [1,2,3,4,5]
df = dataset.iloc[:, k] 
X = dataset.iloc[:, k].values
Y = dataset.iloc[:, 8].values
len(X[0])
df
# Out:
#     Issue with - Drinking/Supply Parts needed  Quantity of Parts - (OFP)  \
# 0                       Drinking          Tap                         15
# 1                       Drinking          Tap                          7
# 2                         Supply          Tap                         19
# 3                         Supply          Tap                          4
# 4                       Drinking         Pipe                         14
# 5                       Drinking          Tap                         25
# 6                       Drinking          Tap                         29
# 7                       Drinking         Pipe                         10
# 8                         Supply      Bassers                         13
# 9                         Supply      Bassers                          2
# 10                      Drinking      Bassers                         21
# 11                        Supply          Tap                          6
# 12                      Drinking         Pipe                         26
# 13                        Supply         Pipe                         14
# 14                      Drinking          Tap                         22
# 15                        Supply          Tap                         15
# 16                        Supply          Tap                         20
# 17                        Supply          Tap                         13
# 18                        Supply      Bassers                         20
# 19                        Supply         Pipe                          7
# 20                      Drinking         Pipe                         21
# 21                        Supply         Pipe                          5
# 22                        Supply          Tap                         12
# 23                      Drinking         Pipe                          9
# 24                        Supply         Pipe                         19
# 25                      Drinking         Pipe                          8
# 26                        Supply      Bassers                         23
# 27                      Drinking         Pipe                         22
# 28                      Drinking          Tap                         24
# 29                        Supply          Tap                          4
# 30                      Drinking          Tap                         14
# 31                        Supply      Bassers                         18
# 32                        Supply          Tap                         26
# 33                        Supply          Tap                         25
# 34                        Supply          Tap                         19
# 35                        Supply          Tap                         16
# 36                        Supply          Tap                         30
# 37                      Drinking      Bassers                         10
# 38                      Drinking         Pipe                         29
# 39                      Drinking         Pipe                         16
# 40                      Drinking      Bassers                         11
# 41                        Supply         Pipe                          8
# 42                        Supply          Tap                         19
# 43                      Drinking         Pipe                          3
# 44                        Supply         Pipe                         24
# 45                      Drinking          Tap                          8
# 46                      Drinking          Tap                         27
# 47                      Drinking      Bassers                         12
# 48                        Supply         Pipe                         25
#
#    Availablity - Available/Need to Order - (OFP)  \
# 0                                  Need To Order
# 1                                  Need To Order
# 2                                  Need To Order
# 3                                      Available
# 4                                      Available
# 5                                  Need To Order
# 6                                      Available
# 7                                      Available
# 8                                      Available
# 9                                  Need To Order
# 10                                     Available
# 11                                     Available
# 12                                 Need To Order
# 13                                 Need To Order
# 14                                 Need To Order
# 15                                     Available
# 16                                 Need To Order
# 17                                 Need To Order
# 18                                 Need To Order
# 19                                 Need To Order
# 20                                     Available
# 21                                 Need To Order
# 22                                     Available
# 23                                 Need To Order
# 24                                 Need To Order
# 25                                 Need To Order
# 26                                     Available
# 27                                 Need To Order
# 28                                 Need To Order
# 29                                 Need To Order
# 30                                 Need To Order
# 31                                 Need To Order
# 32                                     Available
# 33                                     Available
# 34                                 Need To Order
# 35                                     Available
# 36                                 Need To Order
# 37                                 Need To Order
# 38                                 Need To Order
# 39                                 Need To Order
# 40                                     Available
# 41                                     Available
# 42                                 Need To Order
# 43                                 Need To Order
# 44                                     Available
# 45                                     Available
# 46                                     Available
# 47                                     Available
# 48                                     Available
#
#    Need of external expert - (OFP)
# 0                              Yes
# 1                               No
# 2                              Yes
# 3                               No
# 4                               No
# 5                              Yes
# 6                               No
# 7                               No
# 8                              Yes
# 9                              Yes
# 10                             Yes
# 11                             Yes
# 12                              No
# 13                             Yes
# 14                              No
# 15                             Yes
# 16                             Yes
# 17                             Yes
# 18                              No
# 19                              No
# 20                             Yes
# 21                              No
# 22                              No
# 23                             Yes
# 24                              No
# 25                              No
# 26                              No
# 27                             Yes
# 28                             Yes
# 29                              No
# 30                              No
# 31                              No
# 32                              No
# 33                             Yes
# 34                              No
# 35                              No
# 36                              No
# 37                             Yes
# 38                             Yes
# 39                              No
# 40                             Yes
# 41                             Yes
# 42                             Yes
# 43                              No
# 44                             Yes
# 45                             Yes
# 46                              No
# 47                              No
# 48                              No

# %%
# Save Encoder Objects for new incoming data
import pickle
encx0 = LabelEncoder().fit(X[:,0])
encx1 = LabelEncoder().fit(X[:,1])
encx3 = LabelEncoder().fit(X[:,3])
encx4 = LabelEncoder().fit(X[:,4])
filename = 'water_supply/watersupplyencx0.sav'
pickle.dump(encx0,open(filename,'wb'))
filename = 'water_supply/watersupplyencx1.sav'
pickle.dump(encx1,open(filename,'wb'))
filename = 'water_supply/watersupplyencx3.sav'
pickle.dump(encx3,open(filename,'wb'))
filename = 'water_supply/watersupplyencx4.sav'
pickle.dump(encx4,open(filename,'wb'))

# %%
data = ['Drinking','Pipe',3,'Available','No']

# %%
X[:,0] = encx0.transform(X[:,0])
X[:,1] = encx1.transform(X[:,1])
X[:,3] = encx3.transform(X[:,3])
X[:,4] = encx4.transform(X[:,4])

# %%
print(max(X[:,1]))
# Out:
# 1.0

# %%
onehotencoder = OneHotEncoder(categorical_features=[0,1,3,4])
onehenc = onehotencoder.fit(X)
filename = 'water_supply/water_supplyonehenc.sav'
pickle.dump(onehenc,open(filename,'wb'))
X = onehenc.transform(X).toarray()
d = encx0.transform([data[0]])
data[0] = d[0]
d = encx1.transform([data[1]])
data[1] = d[0]
d = encx3.transform([data[3]])
data[3] = d[0]
d = encx4.transform([data[4]])
data[4] = d[0]
ar = np.array(data)
print(data)
ar = ar.reshape(1,-1)
kar=onehenc.transform(ar).toarray()
print(kar)
print(len(X[0]))
# Out:
# [0, 1, 3, 0, 0]
# [[1. 0. 0. 1. 0. 1. 0. 1. 0. 3.]]
# 10

# %%
k = list()
notlist = [0,2,5,7]
for i in range(10):
    if i not in notlist:
        k.append(i)
X = X[:,k]
kar = kar[:,k]

# %%
print(len(X[0]))
# Out:
# 6

# %% [markdown]
# ## SVR

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model1 = SVR(kernel='rbf')
model1.fit(X_train,Y_train)
Y_pred = model1.predict(X_test)

# %%
Y_pred
# Out:
# array([5.33840943, 4.97953718, 4.1835386 , 5.27710442, 4.21209584,
#        5.40729348, 7.22266659, 5.34536141, 5.40865921, 5.66718552])

# %%
Y_test
# Out:
# array([7, 8, 2, 7, 3, 6, 7, 3, 5, 4])

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'C':[1,10,100,1000], 'kernel': ['rbf'], 'gamma':[0.05,0.01,0.001,0.0001]},
             {'C':[100,200,300,400], 'kernel': ['poly'], 'gamma':[0.05,0.06,0.07,0.08,0.09,0.1]},
             {'C':[1,10,100,1000], 'kernel': ['sigmoid'], 'gamma':[0.05,0.01,0.001,0.0001]}]
gridsearch = GridSearchCV(estimator=model1,
                         param_grid=parameters,
                         scoring='r2',
                         cv=10)
gridsearch = gridsearch.fit(X_train,Y_train)
print(gridsearch.best_score_)
print(gridsearch.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-d4bcd2e506b2> in <module>
#       7                          scoring='r2',
#       8                          cv=10)
# ----> 9 gridsearch = gridsearch.fit(X_train,Y_train)
#      10 print(gridsearch.best_score_)
#      11 print(gridsearch.best_params_)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     456             estimator.fit(X_train, **fit_params)
#     457         else:
# --> 458             estimator.fit(X_train, y_train, **fit_params)
#     459
#     460     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model2 = RandomForestRegressor(n_estimators=700, criterion='mse',random_state=0)
model2 = model2.fit(X,Y)

# %%
from sklearn.metrics import r2_score
Y_pred = model2.predict(X)
print(Y_pred)
print(Y_test)
print(r2_score(Y,Y_pred))
# Out:
# [6.43       5.06428571 7.89142857 4.81285714 7.01714286 4.05714286
#  4.85571429 5.27285714 3.85285714 6.61428571 4.76714286 5.94285714
#  5.79285714 4.54428571 3.89142857 7.31142857 8.44857143 4.03
#  6.39857143 4.33857143 5.48428571 5.14571429 5.26285714 6.13857143
#  4.73285714 4.42       2.75857143 4.27857143 5.67857143 6.25142857
#  6.48428571 6.5        3.63142857 3.97       7.18       7.43428571
#  6.11714286 5.77142857 5.36571429 4.70428571 4.03142857 4.90285714
#  7.89142857 5.75857143 3.48857143 3.96       4.11714286 6.73428571
#  3.78857143]
# [7 8 2 7 3 6 7 3 5 4]
# 0.8650034709906258

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'n_estimators':[10,20,30,40,60,70,80,90,100], 'criterion':['mse','mae']}]
grid_search = GridSearchCV(estimator=model2,
                          param_grid=parameters,
                          scoring='r2',
                          cv=10)
grid_search = grid_search.fit(X,Y)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# -0.1648039911235912
# {'criterion': 'mae', 'n_estimators': 40}

# %%
import pickle
filename = 'water_supply/water_supplymodel.sav'
pickle.dump(model2,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(kar)
print(result)
from sklearn.metrics import r2_score
# Out:
# [5.31714286]

# %%
from sklearn.preprocessing import LabelEncoder
c = ['France', 'UK', 'US', 'US', 'UK', 'China', 'France']
enc = LabelEncoder().fit(c)
encoded = enc.transform(c)
print(encoded)

enc.transform(['France'])
# Out:
# [1 2 3 3 2 0 1]
# array([1])

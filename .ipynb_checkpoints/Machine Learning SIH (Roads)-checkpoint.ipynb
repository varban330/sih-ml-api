# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# ## Roads

# %%
dataset = pd.read_csv('Roads/Roads.csv')
dataset
# Out:
#    Grievance Subject Issue with - New Road/ Road Repair  \
# 0           Not Reqd                        Road Repair
# 1           Not Reqd                        Road Repair
# 2           Not Reqd                           New Road
# 3           Not Reqd                           New Road
# 4           Not Reqd                        Road Repair
# 5           Not Reqd                           New Road
# 6           Not Reqd                           New Road
# 7           Not Reqd                           New Road
# 8           Not Reqd                           New Road
# 9           Not Reqd                           New Road
# 10          Not Reqd                           New Road
# 11          Not Reqd                           New Road
# 12          Not Reqd                        Road Repair
# 13          Not Reqd                           New Road
# 14          Not Reqd                           New Road
# 15          Not Reqd                        Road Repair
# 16          Not Reqd                        Road Repair
# 17          Not Reqd                           New Road
# 18          Not Reqd                        Road Repair
# 19          Not Reqd                        Road Repair
# 20          Not Reqd                        Road Repair
# 21          Not Reqd                        Road Repair
# 22          Not Reqd                           New Road
# 23          Not Reqd                           New Road
# 24          Not Reqd                        Road Repair
# 25          Not Reqd                           New Road
# 26          Not Reqd                        Road Repair
# 27          Not Reqd                           New Road
# 28          Not Reqd                           New Road
# 29          Not Reqd                           New Road
# 30          Not Reqd                           New Road
# 31          Not Reqd                           New Road
# 32          Not Reqd                        Road Repair
# 33          Not Reqd                        Road Repair
# 34          Not Reqd                           New Road
# 35          Not Reqd                           New Road
# 36          Not Reqd                           New Road
# 37          Not Reqd                        Road Repair
# 38          Not Reqd                           New Road
# 39          Not Reqd                        Road Repair
# 40          Not Reqd                           New Road
# 41          Not Reqd                        Road Repair
# 42          Not Reqd                           New Road
# 43          Not Reqd                        Road Repair
# 44          Not Reqd                        Road Repair
# 45          Not Reqd                        Road Repair
# 46          Not Reqd                           New Road
# 47          Not Reqd                           New Road
# 48          Not Reqd                           New Road
#
#     Material Needed - (OFP) Availability - (OFP) Manpower required - (OFP)  \
# 0                        20        Need To Order                        No
# 1                        15        Need To Order                       Yes
# 2                         7            Available                       Yes
# 3                        45        Need To Order                        No
# 4                        48            Available                        No
# 5                        26        Need To Order                        No
# 6                        12            Available                       Yes
# 7                         6        Need To Order                       Yes
# 8                        23            Available                       Yes
# 9                        46        Need To Order                       Yes
# 10                        3        Need To Order                        No
# 11                        7        Need To Order                       Yes
# 12                       89            Available                        No
# 13                        2            Available                       Yes
# 14                        1            Available                        No
# 15                       62            Available                        No
# 16                       32            Available                        No
# 17                       47            Available                       Yes
# 18                       12        Need To Order                        No
# 19                       32            Available                       Yes
# 20                        5            Available                       Yes
# 21                        4            Available                        No
# 22                       45            Available                       Yes
# 23                        7        Need To Order                        No
# 24                        9        Need To Order                        No
# 25                       79            Available                        No
# 26                       97            Available                       Yes
# 27                       54            Available                       Yes
# 28                        2            Available                        No
# 29                        6        Need To Order                       Yes
# 30                       62        Need To Order                       Yes
# 31                       26        Need To Order                       Yes
# 32                       13            Available                       Yes
# 33                        1            Available                       Yes
# 34                        3        Need To Order                        No
# 35                       31            Available                       Yes
# 36                       64            Available                       Yes
# 37                       46        Need To Order                        No
# 38                        6        Need To Order                       Yes
# 39                        4        Need To Order                       Yes
# 40                       51            Available                       Yes
# 41                       15            Available                        No
# 42                        1        Need To Order                        No
# 43                        5            Available                        No
# 44                        8            Available                        No
# 45                        3        Need To Order                       Yes
# 46                       38        Need To Order                        No
# 47                       83        Need To Order                       Yes
# 48                       16        Need To Order                       Yes
#
#    Need of Special Machinery - (OFP) Grievance Description  \
# 0                                Yes              Not Reqd
# 1                                Yes              Not Reqd
# 2                                Yes              Not Reqd
# 3                                Yes              Not Reqd
# 4                                Yes              Not Reqd
# 5                                Yes              Not Reqd
# 6                                 No              Not Reqd
# 7                                Yes              Not Reqd
# 8                                 No              Not Reqd
# 9                                 No              Not Reqd
# 10                               Yes              Not Reqd
# 11                               Yes              Not Reqd
# 12                                No              Not Reqd
# 13                               Yes              Not Reqd
# 14                               Yes              Not Reqd
# 15                                No              Not Reqd
# 16                               Yes              Not Reqd
# 17                               Yes              Not Reqd
# 18                                No              Not Reqd
# 19                               Yes              Not Reqd
# 20                                No              Not Reqd
# 21                               Yes              Not Reqd
# 22                               Yes              Not Reqd
# 23                                No              Not Reqd
# 24                                No              Not Reqd
# 25                                No              Not Reqd
# 26                               Yes              Not Reqd
# 27                               Yes              Not Reqd
# 28                                No              Not Reqd
# 29                               Yes              Not Reqd
# 30                               Yes              Not Reqd
# 31                               Yes              Not Reqd
# 32                               Yes              Not Reqd
# 33                                No              Not Reqd
# 34                               Yes              Not Reqd
# 35                               Yes              Not Reqd
# 36                                No              Not Reqd
# 37                               Yes              Not Reqd
# 38                               Yes              Not Reqd
# 39                                No              Not Reqd
# 40                               Yes              Not Reqd
# 41                               Yes              Not Reqd
# 42                               Yes              Not Reqd
# 43                                No              Not Reqd
# 44                                No              Not Reqd
# 45                               Yes              Not Reqd
# 46                                No              Not Reqd
# 47                                No              Not Reqd
# 48                               Yes              Not Reqd
#
#     Days till response - (Prediction)
# 0                                  30
# 1                                  26
# 2                                  26
# 3                                  24
# 4                                  25
# 5                                  30
# 6                                  18
# 7                                  15
# 8                                  23
# 9                                  30
# 10                                 17
# 11                                 21
# 12                                 30
# 13                                 25
# 14                                 28
# 15                                 17
# 16                                 28
# 17                                 25
# 18                                 17
# 19                                 22
# 20                                 14
# 21                                 18
# 22                                 12
# 23                                 27
# 24                                 23
# 25                                 22
# 26                                 29
# 27                                 10
# 28                                 19
# 29                                 29
# 30                                 26
# 31                                 18
# 32                                 11
# 33                                 13
# 34                                 16
# 35                                 30
# 36                                 14
# 37                                 30
# 38                                 26
# 39                                 23
# 40                                 22
# 41                                 28
# 42                                 24
# 43                                 23
# 44                                 21
# 45                                 28
# 46                                 30
# 47                                 26
# 48                                 14

# %%
k = [1,2,3,4,5]
df = dataset.iloc[:, k] 
X = dataset.iloc[:, k].values
Y = dataset.iloc[:, 7].values
len(X[0])
df
# Out:
#    Issue with - New Road/ Road Repair  Material Needed - (OFP)  \
# 0                         Road Repair                       20
# 1                         Road Repair                       15
# 2                            New Road                        7
# 3                            New Road                       45
# 4                         Road Repair                       48
# 5                            New Road                       26
# 6                            New Road                       12
# 7                            New Road                        6
# 8                            New Road                       23
# 9                            New Road                       46
# 10                           New Road                        3
# 11                           New Road                        7
# 12                        Road Repair                       89
# 13                           New Road                        2
# 14                           New Road                        1
# 15                        Road Repair                       62
# 16                        Road Repair                       32
# 17                           New Road                       47
# 18                        Road Repair                       12
# 19                        Road Repair                       32
# 20                        Road Repair                        5
# 21                        Road Repair                        4
# 22                           New Road                       45
# 23                           New Road                        7
# 24                        Road Repair                        9
# 25                           New Road                       79
# 26                        Road Repair                       97
# 27                           New Road                       54
# 28                           New Road                        2
# 29                           New Road                        6
# 30                           New Road                       62
# 31                           New Road                       26
# 32                        Road Repair                       13
# 33                        Road Repair                        1
# 34                           New Road                        3
# 35                           New Road                       31
# 36                           New Road                       64
# 37                        Road Repair                       46
# 38                           New Road                        6
# 39                        Road Repair                        4
# 40                           New Road                       51
# 41                        Road Repair                       15
# 42                           New Road                        1
# 43                        Road Repair                        5
# 44                        Road Repair                        8
# 45                        Road Repair                        3
# 46                           New Road                       38
# 47                           New Road                       83
# 48                           New Road                       16
#
#    Availability - (OFP) Manpower required - (OFP)  \
# 0         Need To Order                        No
# 1         Need To Order                       Yes
# 2             Available                       Yes
# 3         Need To Order                        No
# 4             Available                        No
# 5         Need To Order                        No
# 6             Available                       Yes
# 7         Need To Order                       Yes
# 8             Available                       Yes
# 9         Need To Order                       Yes
# 10        Need To Order                        No
# 11        Need To Order                       Yes
# 12            Available                        No
# 13            Available                       Yes
# 14            Available                        No
# 15            Available                        No
# 16            Available                        No
# 17            Available                       Yes
# 18        Need To Order                        No
# 19            Available                       Yes
# 20            Available                       Yes
# 21            Available                        No
# 22            Available                       Yes
# 23        Need To Order                        No
# 24        Need To Order                        No
# 25            Available                        No
# 26            Available                       Yes
# 27            Available                       Yes
# 28            Available                        No
# 29        Need To Order                       Yes
# 30        Need To Order                       Yes
# 31        Need To Order                       Yes
# 32            Available                       Yes
# 33            Available                       Yes
# 34        Need To Order                        No
# 35            Available                       Yes
# 36            Available                       Yes
# 37        Need To Order                        No
# 38        Need To Order                       Yes
# 39        Need To Order                       Yes
# 40            Available                       Yes
# 41            Available                        No
# 42        Need To Order                        No
# 43            Available                        No
# 44            Available                        No
# 45        Need To Order                       Yes
# 46        Need To Order                        No
# 47        Need To Order                       Yes
# 48        Need To Order                       Yes
#
#    Need of Special Machinery - (OFP)
# 0                                Yes
# 1                                Yes
# 2                                Yes
# 3                                Yes
# 4                                Yes
# 5                                Yes
# 6                                 No
# 7                                Yes
# 8                                 No
# 9                                 No
# 10                               Yes
# 11                               Yes
# 12                                No
# 13                               Yes
# 14                               Yes
# 15                                No
# 16                               Yes
# 17                               Yes
# 18                                No
# 19                               Yes
# 20                                No
# 21                               Yes
# 22                               Yes
# 23                                No
# 24                                No
# 25                                No
# 26                               Yes
# 27                               Yes
# 28                                No
# 29                               Yes
# 30                               Yes
# 31                               Yes
# 32                               Yes
# 33                                No
# 34                               Yes
# 35                               Yes
# 36                                No
# 37                               Yes
# 38                               Yes
# 39                                No
# 40                               Yes
# 41                               Yes
# 42                               Yes
# 43                                No
# 44                                No
# 45                               Yes
# 46                                No
# 47                                No
# 48                               Yes

# %%
# Save Encoder Objects for new incoming data
import pickle
encx0 = LabelEncoder().fit(X[:,0])
encx2 = LabelEncoder().fit(X[:,2])
encx3 = LabelEncoder().fit(X[:,3])
encx4 = LabelEncoder().fit(X[:,4])
filename = 'Roads/Roadsencx0.sav'
pickle.dump(encx0,open(filename,'wb'))
filename = 'Roads/Roadsencx2.sav'
pickle.dump(encx2,open(filename,'wb'))
filename = 'Roads/Roadsencx3.sav'
pickle.dump(encx3,open(filename,'wb'))
filename = 'Roads/Roadsencx4.sav'
pickle.dump(encx4,open(filename,'wb'))

# %%
data = ['Road Repair',5,'Available','No','Yes']

# %%
X[:,0] = encx0.transform(X[:,0])
X[:,2] = encx2.transform(X[:,2])
X[:,3] = encx3.transform(X[:,3])
X[:,4] = encx4.transform(X[:,4])

# %%
print(max(X[:,0]))
# Out:
# 1

# %%
onehotencoder = OneHotEncoder(categorical_features=[0,2,3,4])
onehenc = onehotencoder.fit(X)
filename = 'Roads/Roadsonehenc.sav'
pickle.dump(onehenc,open(filename,'wb'))
X = onehenc.transform(X).toarray()
d = encx0.transform([data[0]])
data[0] = d[0]
d = encx2.transform([data[2]])
data[2] = d[0]
d = encx3.transform([data[3]])
data[3] = d[0]
d = encx3.transform([data[4]])
data[4] = d[0]
ar = np.array(data)
print(data)
ar = ar.reshape(1,-1)
kar=onehenc.transform(ar).toarray()
print(kar)
print(len(X[0]))
# Out:
# [1, 5, 0, 0, 1]
# [[0. 1. 1. 0. 1. 0. 0. 1. 5.]]
# 9

# %%
k = list()
notlist = [0,2,4,6]
for i in range(9):
    if i not in notlist:
        k.append(i)
X = X[:,k]
kar = kar[:,k]

# %%
print((kar[0]))
# Out:
# [1. 0. 0. 1. 5.]

# %% [markdown]
# ## SVR

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model1 = SVR(kernel='rbf')
model1.fit(X_train,Y_train)
Y_pred = model1.predict(X_test)

# %%
Y_pred
# Out:
# array([24.27297228, 24.3310965 , 23.68805513, 22.93752784, 23.30975434,
#        24.25887793, 23.73794449, 23.56730303, 24.27297228, 23.73794449])

# %%
Y_test
# Out:
# array([29, 25, 29, 26, 11, 30, 16, 22, 15, 17])

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'C':[1,10,100,1000], 'kernel': ['rbf'], 'gamma':[0.05,0.01,0.001,0.0001]},
             {'C':[100,200,300,400], 'kernel': ['poly'], 'gamma':[0.05,0.06,0.07,0.08,0.09,0.1]},
             {'C':[1,10,100,1000], 'kernel': ['sigmoid'], 'gamma':[0.05,0.01,0.001,0.0001]}]
gridsearch = GridSearchCV(estimator=model1,
                         param_grid=parameters,
                         scoring='r2',
                         cv=10)
gridsearch = gridsearch.fit(X_train,Y_train)
print(gridsearch.best_score_)
print(gridsearch.best_params_)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
model2 = RandomForestRegressor(n_estimators=1000, criterion='mse',random_state=0)
model2 = model2.fit(X,Y)

# %%
from sklearn.metrics import r2_score
Y_pred = model2.predict(X)
for i in Y_pred:
    print(round(i))
print(Y_test)
print(r2_score(Y,Y_pred))
# Out:
# 11.0
# 5.0
# 7.0
# 6.0
# 9.0
# 9.0
# 7.0
# 12.0
# 7.0
# 8.0
# 12.0
# 8.0
# 7.0
# 7.0
# 5.0
# 8.0
# 8.0
# 8.0
# 7.0
# 5.0
# 7.0
# 7.0
# 8.0
# 9.0
# 9.0
# 11.0
# 7.0
# 8.0
# 5.0
# 12.0
# 5.0
# 11.0
# 7.0
# 11.0
# 6.0
# 13.0
# 8.0
# 9.0
# 5.0
# 10.0
# 8.0
# 7.0
# 8.0
# 8.0
# 9.0
# 7.0
# 13.0
# 5.0
# 4.0
# [13  9  8  4  6 10  6  8 13 12]
# 0.9160157236330498

# %%
from sklearn.model_selection import GridSearchCV
parameters = [{'n_estimators':[1,10,100,1000], 'criterion':['mse','mae']}]
grid_search = GridSearchCV(estimator=model2,
                          param_grid=parameters,
                          scoring='r2',
                          cv=10)
grid_search = grid_search.fit(X,Y)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# -0.6208868019912889
# {'criterion': 'mse', 'n_estimators': 1000}

# %%
import pickle
filename = 'Roads/Roadsmodel.sav'
pickle.dump(model2,open(filename,'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-68618c91e655> in <module>
#       1 import pickle
#       2 filename = 'Roads/Roadsmodel.sav'
# ----> 3 pickle.dump(model2,open(filename,'wb'))
#
# NameError: name 'model2' is not defined

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(kar)
print(result)
from sklearn.metrics import r2_score
# Out:
# [6.834]

# %%
from sklearn.preprocessing import LabelEncoder
c = ['France', 'UK', 'US', 'US', 'UK', 'China', 'France']
enc = LabelEncoder().fit(c)
encoded = enc.transform(c)
print(encoded)

enc.transform(['France'])
# Out:
# [1 2 3 3 2 0 1]
# array([1])

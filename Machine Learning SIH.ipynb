# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %% [markdown]
# ## Mess (Hr)

# %%
dataset = pd.read_csv('Mess(hr).csv')
dataset
# Out:
#    Grievance Subject Hostel Transaction Mode Bank used by Payee  \
# 0           Not Reqd      N           CHEQUE              ICICI
# 1           Not Reqd      I           CHEQUE               HDFC
# 2           Not Reqd      I             NEFT               HDFC
# 3           Not Reqd      L            PAYTM               HDFC
# 4           Not Reqd      B             NEFT               HDFC
# 5           Not Reqd      H           CHEQUE              ICICI
# 6           Not Reqd     PG           CHEQUE              ICICI
# 7           Not Reqd      A               DD              ICICI
# 8           Not Reqd      L           CHEQUE                SBI
# 9           Not Reqd      I             NEFT                SBI
# 10          Not Reqd      H          CHALLAN              ICICI
# 11          Not Reqd      N             NEFT              ICICI
# 12          Not Reqd      N           CHEQUE               HDFC
# 13          Not Reqd      K          CHALLAN                SBI
# 14          Not Reqd     PG             NEFT              ICICI
# 15          Not Reqd      K               DD              ICICI
# 16          Not Reqd      B               DD                SBI
# 17          Not Reqd      E            PAYTM                SBI
# 18          Not Reqd      N           CHEQUE               HDFC
# 19          Not Reqd      H           CHEQUE                SBI
# 20          Not Reqd      K               DD              ICICI
# 21          Not Reqd      I             NEFT               HDFC
# 22          Not Reqd      B             NEFT               HDFC
# 23          Not Reqd      H             NEFT              ICICI
# 24          Not Reqd      L            PAYTM                SBI
# 25          Not Reqd      M           CHEQUE               HDFC
# 26          Not Reqd      N               DD               HDFC
# 27          Not Reqd      I               DD                SBI
# 28          Not Reqd      L            PAYTM               HDFC
# 29          Not Reqd      K           CHEQUE              ICICI
# 30          Not Reqd      I             NEFT               HDFC
# 31          Not Reqd      L           CHEQUE                SBI
# 32          Not Reqd      K           CHEQUE                SBI
# 33          Not Reqd      L          CHALLAN              ICICI
# 34          Not Reqd      J            PAYTM                SBI
# 35          Not Reqd      I               DD              ICICI
# 36          Not Reqd     PG            PAYTM              ICICI
# 37          Not Reqd      L           CHEQUE               HDFC
# 38          Not Reqd      A             NEFT               HDFC
# 39          Not Reqd      A           CHEQUE              ICICI
# 40          Not Reqd      G            PAYTM                SBI
# 41          Not Reqd      N             NEFT              ICICI
# 42          Not Reqd      A             NEFT               HDFC
# 43          Not Reqd      H           CHEQUE               HDFC
# 44          Not Reqd      B            PAYTM                SBI
# 45          Not Reqd      E           CHEQUE                SBI
# 46          Not Reqd      G          CHALLAN                SBI
# 47          Not Reqd      I           CHEQUE                SBI
# 48          Not Reqd      H             NEFT              ICICI
#
#     Transaction Number  Account Number of Payee Grievance Description  \
# 0           1761066513             9.557100e+11              Not Reqd
# 1           1893755115             9.194830e+11              Not Reqd
# 2           1775178520             9.464250e+11              Not Reqd
# 3           1010544585             9.242710e+11              Not Reqd
# 4           1296796242             9.905370e+11              Not Reqd
# 5           1701715302             9.153680e+11              Not Reqd
# 6           1612845749             9.029840e+11              Not Reqd
# 7           1831049838             9.222150e+11              Not Reqd
# 8           1546496994             9.983440e+11              Not Reqd
# 9           1566630364             9.535760e+11              Not Reqd
# 10          1972069453             9.959480e+11              Not Reqd
# 11          1386028918             9.875670e+11              Not Reqd
# 12          1321337058             9.268620e+11              Not Reqd
# 13          1538166021             9.729610e+11              Not Reqd
# 14          1461823103             9.433800e+11              Not Reqd
# 15          1861695090             9.438490e+11              Not Reqd
# 16          1977635728             9.042400e+11              Not Reqd
# 17          1185236196             9.445880e+11              Not Reqd
# 18          1804805964             9.531790e+11              Not Reqd
# 19          1576723475             9.716840e+11              Not Reqd
# 20          1011221546             9.605580e+11              Not Reqd
# 21          1562372372             9.815550e+11              Not Reqd
# 22          1717884256             9.072450e+11              Not Reqd
# 23          1597378377             9.064710e+11              Not Reqd
# 24          1008882757             9.295120e+11              Not Reqd
# 25          1194255569             9.159620e+11              Not Reqd
# 26          1603047509             9.585270e+11              Not Reqd
# 27          1301725943             9.829400e+11              Not Reqd
# 28          1083466337             9.935200e+11              Not Reqd
# 29          1483147745             9.635580e+11              Not Reqd
# 30          1439543637             9.447840e+11              Not Reqd
# 31          1743766226             9.303020e+11              Not Reqd
# 32          1898419493             9.848960e+11              Not Reqd
# 33          1521696939             9.705300e+11              Not Reqd
# 34          1298763252             9.673580e+11              Not Reqd
# 35          1974176721             9.140100e+11              Not Reqd
# 36          1175443079             9.856430e+11              Not Reqd
# 37          1315497669             9.447650e+11              Not Reqd
# 38          1917428707             9.432470e+11              Not Reqd
# 39          1148066016             9.355670e+11              Not Reqd
# 40          1442432731             9.129390e+11              Not Reqd
# 41          1736345795             9.779060e+11              Not Reqd
# 42          1692638623             9.790000e+11              Not Reqd
# 43          1940754922             9.197310e+11              Not Reqd
# 44          1758688106             9.647030e+11              Not Reqd
# 45          1225648659             9.488520e+11              Not Reqd
# 46          1507346424             9.686660e+11              Not Reqd
# 47          1907181731             9.979330e+11              Not Reqd
# 48          1995870785             9.501380e+11              Not Reqd
#
#    Attached Documents  Days till response
# 0            Not Reqd                  12
# 1            Not Reqd                  15
# 2            Not Reqd                   1
# 3            Not Reqd                   5
# 4            Not Reqd                   2
# 5            Not Reqd                   8
# 6            Not Reqd                   6
# 7            Not Reqd                   9
# 8            Not Reqd                   9
# 9            Not Reqd                  12
# 10           Not Reqd                  10
# 11           Not Reqd                   6
# 12           Not Reqd                   7
# 13           Not Reqd                  12
# 14           Not Reqd                   1
# 15           Not Reqd                  11
# 16           Not Reqd                  13
# 17           Not Reqd                  15
# 18           Not Reqd                  11
# 19           Not Reqd                   9
# 20           Not Reqd                  15
# 21           Not Reqd                  10
# 22           Not Reqd                  10
# 23           Not Reqd                   9
# 24           Not Reqd                   8
# 25           Not Reqd                  10
# 26           Not Reqd                   9
# 27           Not Reqd                   4
# 28           Not Reqd                   6
# 29           Not Reqd                   9
# 30           Not Reqd                   6
# 31           Not Reqd                   2
# 32           Not Reqd                   1
# 33           Not Reqd                  14
# 34           Not Reqd                   4
# 35           Not Reqd                  12
# 36           Not Reqd                   8
# 37           Not Reqd                   5
# 38           Not Reqd                  14
# 39           Not Reqd                  15
# 40           Not Reqd                  13
# 41           Not Reqd                   7
# 42           Not Reqd                   7
# 43           Not Reqd                   3
# 44           Not Reqd                   8
# 45           Not Reqd                  15
# 46           Not Reqd                  13
# 47           Not Reqd                   5
# 48           Not Reqd                   1

# %%
X = dataset.iloc[:, 1:4].values
Y = dataset.iloc[:, 8].values

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_X1 = LabelEncoder()
X[:,0] = labelencoder_X1.fit_transform(X[:,0])
labelencoder_X1 = LabelEncoder()
X[:,1] = labelencoder_X1.fit_transform(X[:,1])
labelencoder_X1 = LabelEncoder()
X[:,2] = labelencoder_X1.fit_transform(X[:,2])
onehotencoder = OneHotEncoder(categorical_features=[0,1,2])
X = onehotencoder.fit_transform(X).toarray()

# %%
k = list()
for i in range(20):
    if i!=0 and i!=12 and i!=17:
        k.append(i)
X = X[:,k]
print(len(X[0]))
# Out:
# 17
